# %%
import pandas as pd

jobs = pd.read_csv("../data/processed/jobs_with_skills.csv")

jobs.head()

# %%
jobs.columns

# %%
jobs['extracted_skills'].head()

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
jobs['skills_text'] = jobs['extracted_skills'].astype(str)

# %%
jobs[['skills_text']].head()

# %%
jobs['skills_text'].value_counts().head()
